# %%
from google.colab import files
# files.upload() # https://www.kaggle.com/competitions/titanic/data?select=train.csv

# %% [markdown]
# # Data Pre-Processing

# %%
import pandas as pd

test_df = pd.read_csv('/content/test.csv')
train_df = pd.read_csv('/content/train.csv')
test_ids = test_df["PassengerId"]

def clean(data):
  data = data.drop(["Ticket", "Cabin", "Name", "PassengerId"], axis=1)

  cols = ["SibSp", "Parch", "Fare", "Age"]
  for col in cols:
    # data[col].fillna(data[col].median(), inplace=True)
    data[col] = data[col].fillna(data[col].median())

  # data.Embarked.fillna("U", inplace=True)
  data.Embarked = data.Embarked.fillna("U")
  return data

test_df = clean(test_df)
train_df = clean(train_df)

train_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1255140804.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 test_df = pd.read_csv('/content/test.csv')
#       4 train_df = pd.read_csv('/content/train.csv')
#       5 test_ids = test_df["PassengerId"]
#
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

cols = ["Sex", "Embarked"]
for col in cols:
  train_df[col] = le.fit_transform(train_df[col])
  test_df[col] = le.transform(test_df[col])
  print(le.classes_)

train_df.head(5)
test_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2578841370.py in <cell line: 0>()
#       4 cols = ["Sex", "Embarked"]
#       5 for col in cols:
# ----> 6   train_df[col] = le.fit_transform(train_df[col])
#       7   test_df[col] = le.transform(test_df[col])
#       8   print(le.classes_)
#
# NameError: name 'train_df' is not defined

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
y = train_df["Survived"]
X = train_df.drop("Survived", axis=1)

# Create Train/Val Split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# ## Linear Regression - 76.56%

# %%
"""
# Train and validate data
clf = LogisticRegression(max_iter=1000,).fit(X_train, y_train)
predictions = clf.predict(X_val)
accuracy_score(y_val, predictions)

# LinearRegression Submission
submission_preds = clf.predict(test_df)
df = pd.DataFrame({"PassengerId": test_ids.values,
                   "Survived": submission_preds})

df.to_csv("titanic_linreg_submission.csv", index=False)
"""

# %% [markdown]
# ## Decision Tree - 73.68%

# %%
"""
# Train and validate data
clf = tree.DecisionTreeClassifier().fit(X_train, y_train)
predictions = clf.predict(X_val)
accuracy_score(y_val, predictions)

# Decision Tree Submission
submission_preds = clf.predict(test_df)
df = pd.DataFrame({"PassengerId": test_ids.values,
                "Survived": submission_preds})

df.to_csv("titanic_tree_submission.csv", index=False)
"""

# %% [markdown]
# ## Random Forest - 76.79%

# %%
"""
# Train and validate data
clf = RandomForestClassifier(max_depth=4).fit(X_train, y_train) # test with different max_depths
predictions = clf.predict(X_val)
accuracy_score(y_val, predictions)

# Decision tree submission
submission_preds = clf.predict(test_df)
df = pd.DataFrame({"PassengerId": test_ids.values,
                   "Survived": submission_preds})

df.to_csv("titanic_forest_submission.csv", index=False)
"""
